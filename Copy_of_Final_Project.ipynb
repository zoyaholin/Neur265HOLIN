# %% [markdown]
# <a href="https://colab.research.google.com/github/zoyaholin/Neur265HOLIN/blob/main/Copy_of_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mpl
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from scipy import stats

# %%
url= 'https://raw.githubusercontent.com/zoyaholin/Neur265HOLIN/main/alzheimers_IDs_final_project.xlsx%20-%20SEA-AD_Cohort_Metadata.csv'
alz_ID= pd.read_csv(url)

url1= 'https://raw.githubusercontent.com/zoyaholin/Neur265HOLIN/main/alzheimers_pathology_final_project.csv'
alz_path= pd.read_csv(url1)

url2= 'https://raw.githubusercontent.com/zoyaholin/Neur265HOLIN/main/Updated%20alz%20-%20Sheet1.csv'
alz_combined= pd.read_csv(url2)

# %%
#Making variables
cog_status= alz_ID.iloc[:,17]
sex=alz_ID.iloc[:,4]

AT8positive_area_Layer3 = alz_path.iloc[:,5]
AT8positive_area_Layer4 = alz_path.iloc[:,6]
totalpTDP43_positive_area_Layer1= alz_path.iloc[:,10]
totalpTDP43_positive_area_Layer2= alz_path.iloc[:,11]

# %%
#Making histogram for AT8 positive layer 3
plt.hist(AT8positive_area_Layer3, color = "pink")
plt.xlabel('AT8 Positive Area Layer 3')
plt.ylabel('Count')
plt.title('Distribution of AT8 Positive Area Layer 3')
# Out:
# Text(0.5, 1.0, 'Distribution of AT8 Positive Area Layer 3')

# %%
#Making histogram for AT8 positive layer 4
plt.hist(AT8positive_area_Layer4, color = "pink")
plt.xlabel('AT8 Positive Area Layer 4')
plt.ylabel('Count')
plt.title('Distribution of AT8 Positive Area Layer 4')
# Out:
# Text(0.5, 1.0, 'Distribution of AT8 Positive Area Layer 4')

# %%
#Making histogram for total pTDP43_positive_area_Layer1
plt.hist(totalpTDP43_positive_area_Layer1, color = "pink")
plt.xlabel('pTDP43_positive_area_Layer1')
plt.ylabel('Count')
plt.title('Distribution of pTDP43_positive_area_Layer1')
# Out:
# Text(0.5, 1.0, 'Distribution of pTDP43_positive_area_Layer1')

# %%
#Making histogram for total pTDP43_positive_area_Layer2
plt.hist(totalpTDP43_positive_area_Layer2, color = "pink")
plt.xlabel('pTDP43_positive_area_Layer2')
plt.ylabel('Count')
plt.title('Distribution of pTDP43_positive_area_Layer2')
# Out:
# Text(0.5, 1.0, 'Distribution of pTDP43_positive_area_Layer2')

# %%
#Making pie chart for cog status grouping variables
colors = ['pink', 'blue']
alz_ID['Cognitive Status'].value_counts().plot(kind='pie', colors=colors)

plt.ylabel('Cognitive Status')
plt.show()

# %%
#Making pie chart for sex grouping variables
colors = ['pink', 'blue']
alz_ID['Sex'].value_counts().plot(kind='pie', colors=colors)

plt.ylabel('Sex')
plt.show()

# %%
#scatter of AT8 layer 3/4
alz_combined_length=len(alz_combined)

for i in range(alz_combined_length):
  if alz_combined.iloc[i,2] == 'Dementia':
    plt.scatter(alz_combined.iloc [i,3], alz_combined.iloc [i,4], color = "blue")
  else: 
    plt.scatter(alz_combined.iloc [i,3], alz_combined.iloc [i,4], color = "pink")
    plt.xlabel('total AT8 positive area Layer3 ')
    plt.ylabel('total AT8 positive area Layer4 ')
    plt.title('Total AT8 Positive Area Layers 3 and 4 Plotted Against Cognitive Status')

plt.legend(['Dementia','Non-Dementia'])

# %%
#Plotting scatter plot for total pTDP43 positive area Layer 1 and total pTDP43 positive area Layer2 
alz_combined_length=len(alz_combined)

for i in range(alz_combined_length):
  if alz_combined.iloc[i,1] == 'Female':
    plt.scatter(alz_combined.iloc [i,5], alz_combined.iloc [i,6], color = "blue")
  else: 
    plt.scatter(alz_combined.iloc [i,5], alz_combined.iloc [i,6], color = "pink")
    plt.xlabel('total pTDP43 positive area Layer 1')
    plt.ylabel('total pTDP43 positive area Layer 2')
    plt.title('Total pTDP43 positive area Layers 1 and 2 Plotted Against Sex')

plt.legend(['Female','Male'])

# %%
#Making variables into numpy arrays

male_pTDP43_1= np.array(alz_combined.loc[alz_combined['Sex'] == 'Male', ['totalpTDP43_positive_area_Layer1']])

female_pTDP43_2 = np.array(alz_combined.loc[alz_combined['Sex'] == 'Female', ['totalpTDP43_positive_area_Layer2']])
male_pTDP43_1 = np.array(alz_combined.loc[alz_combined['Sex'] == 'Male', ['totalpTDP43_positive_area_Layer2']])

Dem_AT8_3 = np.array(alz_combined.loc[alz_combined['Cognitive Status'] == 'Dementia', ['AT8positive_area_Layer3']])
NoDem_AT8_3 = np.array(alz_combined.loc[alz_combined['Cognitive Status'] == 'No Dementia', ['AT8positive_area_Layer4']])

Dem_AT8_4 = np.array(alz_combined.loc[alz_combined['Cognitive Status'] == 'Dementia', ['AT8positive_area_Layer4']])
NoDem_AT8_4= np.array(alz_combined.loc[alz_combined['Cognitive Status'] == 'No Dementia', ['AT8positive_area_Layer4']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-d1741db15b44> in <cell line: 3>()
#       1 #Making variables into numpy arrays
#       2
# ----> 3 male_pTDP43_1= np.array(alz_combined.loc[alz_combined['Sex'] == 'Male', ['totalpTDP43_positive_area_Layer1']])
#       4
#       5 female_pTDP43_2 = np.array(alz_combined.loc[alz_combined['Sex'] == 'Female', ['totalpTDP43_positive_area_Layer2']])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     922                 continue
#     923
# --> 924             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     925             # We should never have retval.ndim < self.ndim, as that should
#     926             #  be handled by the _getitem_lowerdim call above.
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1299                     raise ValueError("Cannot index with multidimensional key")
#    1300
# -> 1301                 return self._getitem_iterable(key, axis=axis)
#    1302
#    1303             # nested tuple slicing
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1237
#    1238         # A collection of keys
# -> 1239         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1240         return self.obj._reindex_with_indexers(
#    1241             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1430         axis_name = self.obj._get_axis_name(axis)
#    1431
# -> 1432         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1433
#    1434         return keyarr, indexer
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6128                 if use_interval_msg:
#    6129                     key = list(key)
# -> 6130                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6131
#    6132             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['totalpTDP43_positive_area_Layer1'], dtype='object')] are in the [columns]"

# %%
a4_GFAP = np.array(alz_combined.loc[alz_combined['APOE4 Status'] == 'Y', ['total GFAP positive area_Grey matter']])
a4_aSyn = np.array(alz_combined.loc[alz_combined['APOE4 Status'] == 'Y', ['total aSyn positive area_Grey matter']])
na_GFAP = np.array(alz_combined.loc[alz_combined['APOE4 Status'] == 'N', ['total GFAP positive area_Grey matter']])
na_aSyn = np.array(alz_combined.loc[alz_combined['APOE4 Status'] == 'N', ['total aSyn positive area_Grey matter']])
D_Tau = np.array(alz_combined.loc[alz_combined['Cognitive Status'] == 'Dementia', ['ripa tTau_Grey matter']])
D_Abeta = np.array(alz_combined.loc[alz_combined['Cognitive Status'] == 'Dementia', ['ripa abeta42_Grey matter']])
ND_Tau = np.array(alz_combined.loc[alz_combined['Cognitive Status'] == 'No dementia', ['ripa tTau_Grey matter']])
ND_Abeta = np.array(alz_combined.loc[alz_combined['Cognitive Status'] == 'No dementia', ['ripa abeta42_Grey matter']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'APOE4 Status'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-1f3de69f79b4> in <cell line: 1>()
# ----> 1 a4_GFAP = np.array(alz_combined.loc[alz_combined['APOE4 Status'] == 'Y', ['total GFAP positive area_Grey matter']])
#       2 a4_aSyn = np.array(alz_combined.loc[alz_combined['APOE4 Status'] == 'Y', ['total aSyn positive area_Grey matter']])
#       3 na_GFAP = np.array(alz_combined.loc[alz_combined['APOE4 Status'] == 'N', ['total GFAP positive area_Grey matter']])
#       4 na_aSyn = np.array(alz_combined.loc[alz_combined['APOE4 Status'] == 'N', ['total aSyn positive area_Grey matter']])
#       5 D_Tau = np.array(alz_combined.loc[alz_combined['Cognitive Status'] == 'Dementia', ['ripa tTau_Grey matter']])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'APOE4 Status'
